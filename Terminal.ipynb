# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Formation OC/P7/monnouveauprojet
# Out:
# /content/drive/MyDrive/Formation OC/P7/monnouveauprojet

# %%
# !git clone https://github.com/RomSlom/monnouveauprojet.git
# Out:
# Cloning into 'monnouveauprojet'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 11 (delta 2), reused 7 (delta 1), pack-reused 0
# ^C

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Formation OC/P7/monnouveauprojet

# %%
# !ls -a
# Out:
#  addended3.ipynb			      Readme
# 'Copy of slomczynski_romain_1_032023.ipynb'   slomczynski_romain_1_032023.ipynb
#  .git					      Terminal.ipynb

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/RomSlom/monnouveauprojet.git (fetch)
# origin	https://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@github.com/RomSlom/monnouveauprojet.git (push)

# %%
# !git status
# Out:
# On branch master
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   Copy of slomczynski_romain_1_032023.ipynb

# %%
# !touch slomczynski_romain_1_032023.ipynb

# %%
# !git add -A

# %%
# !git status
# Out:
# On branch master
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   Copy of slomczynski_romain_1_032023.ipynb

# %%
# !git commit -a -m 'main file copy created'
# Out:
# [master a2d9a32] main file copy created
#  1 file changed, 1 insertion(+)
#  create mode 100644 Copy of slomczynski_romain_1_032023.ipynb

# %%
# !git config --list
# Out:
# filter.lfs.clean=git-lfs clean -- %f
# filter.lfs.smudge=git-lfs smudge -- %f
# filter.lfs.process=git-lfs filter-process
# filter.lfs.required=true
# user.email=slomczynskiromain@yahoo.fr
# user.name=RomSlom
# core.repositoryformatversion=0
# core.filemode=true
# core.bare=false
# core.logallrefupdates=true
# remote.origin.url=https://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@github.com/RomSlom/OpenCR.git
# remote.origin.fetch=+refs/heads/*:refs/remotes/origin/*

# %%
# !git status
# Out:
# On branch master
# nothing to commit, working tree clean

# %%
username = "RomSlom"

# %%
git_token = "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"

# %%
repository = 'monnouveauprojet'

# %%
# !git remote add origin https://{git_token}@github.com/{username}/{repository}.git
# Out:
# fatal: remote origin already exists.

# %%
# !git remote rm origin

# %%
# !git remote add origin https://{git_token}@github.com/{username}/{repository}.git

# %%
# !git push origin master
# Out:
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 782 bytes | 260.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/RomSlom/monnouveauprojet.git
#    f8e7305..a2d9a32  master -> master

# %%
# !git config --global user.email "slomczynskiromain@yahoo.fr"
# !git config --global user.name "RomSlom"

# %%
# !git commit -m "Updated main file"
# Out:
# On branch master
# nothing to commit, working tree clean

# %%
# !git add slomczynski_romain_1_032023.ipynb

# %%
# !git commit -m "Updated main file 2"
# Out:
# On branch master
# nothing to commit, working tree clean

# %%
# !git remote remove origin
# Out:
# fatal: No such remote: 'origin'

# %%
# !git remote -v

# %%
# !git push -u origin master
# Out:
# fatal: 'origin' does not appear to be a git repository
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.

# %%
# !git status
# Out:
# On branch master
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   OpenCR
# 	new file:   addended3.ipynb

# %%
# !git add slomczynski_romain_1_032023.ipynb

# %%
# !cd ..

# %%
# Out:
# /content/drive/MyDrive/GitHub/Projet 7
